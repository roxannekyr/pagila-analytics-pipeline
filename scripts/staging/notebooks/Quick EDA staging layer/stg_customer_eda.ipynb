# %%
from google.cloud import bigquery
import pandas as pd
import seaborn as sns
import matplotlib as plt
import os

#Setting credentials path 
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = r"C:\Users\roxan\AppData\Roaming\gcloud\application_default_credentials.json"

#Using the IDs defined in your relevant staging file
project_id = 'project-401f4646-3663-4125-aaa'
dataset_id = 'staging_db'
table_id = 'stg_customer'  

client = bigquery.Client(project=project_id)

#Querying the table that contains your renamed columns
query = f"SELECT * FROM `{project_id}.{dataset_id}.{table_id}`"

#Assigning the result directly to the variable 'df'
df = client.query(query).to_dataframe()

#Confirming the data loaded correctly
print(df.columns)
print('\n')

display(df.head())
# Out:
# C:\Users\roxan\PycharmProjects\Pagila Analytics Pipeline\.venv\Lib\site-packages\google\cloud\bigquery\table.py:2086: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# Index(['customer_id', 'customer_store_id', 'customer_first_name',
#        'customer_last_name', 'customer_email', 'customer_address_id',
#        'customer_activebool', 'customer_create_date', 'customer_last_update',
#        'customer_active'],
#       dtype='str')
#    customer_id  customer_store_id customer_first_name customer_last_name  \
# 0            1                  1                MARY              SMITH
# 1            3                  1               LINDA           WILLIAMS
# 2            2                  1            PATRICIA            JOHNSON
# 3           17                  1               DONNA           THOMPSON
# 4           15                  1               HELEN             HARRIS
#
#                         customer_email  customer_address_id  \
# 0        MARY.SMITH@sakilacustomer.org                    5
# 1    LINDA.WILLIAMS@sakilacustomer.org                    7
# 2  PATRICIA.JOHNSON@sakilacustomer.org                    6
# 3    DONNA.THOMPSON@sakilacustomer.org                   21
# 4      HELEN.HARRIS@sakilacustomer.org                   19
#
#    customer_activebool customer_create_date customer_last_update  \
# 0                 True           2022-02-14  2022-02-15 09:57:20
# 1                 True           2022-02-14  2022-02-15 09:57:20
# 2                 True           2022-02-14  2022-02-15 09:57:20
# 3                 True           2022-02-14  2022-02-15 09:57:20
# 4                 True           2022-02-14  2022-02-15 09:57:20
#
#    customer_active
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1

# %%
def quick_eda(df):
    """
    Function performing a quick initial Exploratory Data Analysis on DataFrame df.
    """
    print("Checking first 5 rows")
    print(df.head())
    print('\n')

    print("Checking Shape of DataFrame (Rows, Columns)")
    print(df.shape)
    print('\n')

    print("Checking data types of Columns of DataFrame")
    print(df.dtypes)
    print('\n')

    print("Checking value counts per Column for DataFrame")
    print(df.count())
    print('\n')

    print("Checking unique values per Column for DataFrame")
    print(df.nunique())
    print('\n')

    #print("Checking Summary Statistics for numeric columns of DataFrame")
    #print(df.describe().round())
    #print('\n')

    print("Checking info of DataFrame")
    df.info(show_counts=True)
    print('\n')

    print("Checking for missing values in DataFrame")
    print(df.isna().sum())
    print('\n')

    print("Checking for duplicate values in DataFrame")
    print(df.duplicated().sum())
    print('\n')

    return df

# %%
df = quick_eda(df)
# Out:
# Checking first 5 rows
#    customer_id  customer_store_id customer_first_name customer_last_name  \
# 0            1                  1                MARY              SMITH
# 1            3                  1               LINDA           WILLIAMS
# 2            2                  1            PATRICIA            JOHNSON
# 3           17                  1               DONNA           THOMPSON
# 4           15                  1               HELEN             HARRIS
#
#                         customer_email  customer_address_id  \
# 0        MARY.SMITH@sakilacustomer.org                    5
# 1    LINDA.WILLIAMS@sakilacustomer.org                    7
# 2  PATRICIA.JOHNSON@sakilacustomer.org                    6
# 3    DONNA.THOMPSON@sakilacustomer.org                   21
# 4      HELEN.HARRIS@sakilacustomer.org                   19
#
#    customer_activebool customer_create_date customer_last_update  \
# 0                 True           2022-02-14  2022-02-15 09:57:20
# 1                 True           2022-02-14  2022-02-15 09:57:20
# 2                 True           2022-02-14  2022-02-15 09:57:20
# 3                 True           2022-02-14  2022-02-15 09:57:20
# 4                 True           2022-02-14  2022-02-15 09:57:20
#
#    customer_active
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
#
#
# Checking Shape of DataFrame (Rows, Columns)
# (599, 10)
#
#
# Checking data types of Columns of DataFrame
# customer_id                      Int64
# customer_store_id                Int64
# customer_first_name                str
# customer_last_name                 str
# customer_email                     str
# customer_address_id              Int64
# customer_activebool            boolean
# customer_create_date    datetime64[us]
# customer_last_update    datetime64[us]
# customer_active                  Int64
# dtype: object
#
#
# Checking value counts per Column for DataFrame
# customer_id             599
# customer_store_id       599
# customer_first_name     599
# customer_last_name      599
# customer_email          599
# customer_address_id     599
# customer_activebool     599
# customer_create_date    599
# customer_last_update    599
# customer_active         599
# dtype: int64
#
#
# Checking unique values per Column for DataFrame
# customer_id             599
# customer_store_id         2
# customer_first_name     591
# customer_last_name      599
# customer_email          599
# customer_address_id     599
# customer_activebool       1
# customer_create_date      1
# customer_last_update      1
# customer_active           2
# dtype: int64
#
#
# Checking info of DataFrame
# <class 'pandas.DataFrame'>
# RangeIndex: 599 entries, 0 to 598
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   customer_id           599 non-null    Int64
#  1   customer_store_id     599 non-null    Int64
#  2   customer_first_name   599 non-null    str
#  3   customer_last_name    599 non-null    str
#  4   customer_email        599 non-null    str
#  5   customer_address_id   599 non-null    Int64
#  6   customer_activebool   599 non-null    boolean
#  7   customer_create_date  599 non-null    datetime64[us]
#  8   customer_last_update  599 non-null    datetime64[us]
#  9   customer_active       599 non-null    Int64
# dtypes: Int64(4), boolean(1), datetime64[us](2), str(3)
# memory usage: 71.3 KB
#
#
# Checking for missing values in DataFrame
# customer_id             0
# customer_store_id       0
# customer_first_name     0
# customer_last_name      0
# customer_email          0
# customer_address_id     0
# customer_activebool     0
# customer_create_date    0
# customer_last_update    0
# customer_active         0
# dtype: int64
#
#
# Checking for duplicate values in DataFrame
# 0
