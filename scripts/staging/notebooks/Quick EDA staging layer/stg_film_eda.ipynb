# %%
from google.cloud import bigquery
import pandas as pd
import seaborn as sns
import matplotlib as plt
import os

#Setting credentials path 
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = r"C:\Users\roxan\AppData\Roaming\gcloud\application_default_credentials.json"

#Using the IDs defined in your relevant staging file
project_id = 'project-401f4646-3663-4125-aaa'
dataset_id = 'staging_db'
table_id = 'stg_film'  

client = bigquery.Client(project=project_id)

#Querying the table that contains your renamed columns
query = f"SELECT * FROM `{project_id}.{dataset_id}.{table_id}`"

#Assigning the result directly to the variable 'df'
df = client.query(query).to_dataframe()

#Confirming the data loaded correctly
print(df.columns)
print('\n')

display(df.head())
# Out:
# C:\Users\roxan\PycharmProjects\Pagila Analytics Pipeline\.venv\Lib\site-packages\google\cloud\bigquery\table.py:2086: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# Index(['film_id', 'film_title', 'film_description', 'film_language_id',
#        'film_original_language_id', 'film_rental_duration', 'film_rental_rate',
#        'film_length', 'film_replacement_cost', 'film_rating',
#        'film_last_update', 'film_special_features', 'film_fulltext'],
#       dtype='str')
#    film_id              film_title  \
# 0      402            HARPER DYING
# 1       26          ANNIE IDENTITY
# 2      366  GOLDFINGER SENSIBILITY
# 3      901             TRACY CIDER
# 4      247         DOWNHILL ENOUGH
#
#                                     film_description  film_language_id  \
# 0  A Awe-Inspiring Reflection of a Woman And a Ca...                 1
# 1  A Amazing Panorama of a Pastry Chef And a Boat...                 1
# 2  A Insightful Drama of a Mad Scientist And a Hu...                 1
# 3  A Touching Reflection of a Database Administra...                 1
# 4  A Emotional Tale of a Pastry Chef And a Forens...                 1
#
#    film_original_language_id  film_rental_duration film_rental_rate  \
# 0                       <NA>                     3      0.990000000
# 1                       <NA>                     3      0.990000000
# 2                       <NA>                     3      0.990000000
# 3                       <NA>                     3      0.990000000
# 4                       <NA>                     3      0.990000000
#
#    film_length film_replacement_cost film_rating           film_last_update  \
# 0           52          15.990000000           G 2022-09-10 16:46:03.905795
# 1           86          15.990000000           G 2022-09-10 16:46:03.905795
# 2           93          29.990000000           G 2022-09-10 16:46:03.905795
# 3          142          29.990000000           G 2022-09-10 16:46:03.905795
# 4           47          19.990000000           G 2022-09-10 16:46:03.905795
#
#                              film_special_features  \
# 0                                     ["Trailers"]
# 1                ["Commentaries","Deleted Scenes"]
# 2  ["Trailers","Commentaries","Behind the Scenes"]
# 3  ["Trailers","Commentaries","Behind the Scenes"]
# 4     ["Trailers","Commentaries","Deleted Scenes"]
#
#                                        film_fulltext
# 0  'awe':5 'awe-inspir':4 'cat':13 'confront':16 ...
# 1  'abandon':20 'amaz':4 'amus':21 'anni':1 'boat...
# 2  'chef':18 'defeat':15 'drama':5 'goldfing':1 '...
# 3  'administr':9 'build':15 'cider':2 'databas':8...
# 4  'chef':9 'desert':22 'downhil':1 'emot':4 'eno...

# %%
def quick_eda(df):
    """
    Function performing a quick initial Exploratory Data Analysis on DataFrame df.
    """
    print("Checking first 5 rows")
    print(df.head())
    print('\n')

    print("Checking Shape of DataFrame (Rows, Columns)")
    print(df.shape)
    print('\n')

    print("Checking data types of Columns of DataFrame")
    print(df.dtypes)
    print('\n')

    print("Checking value counts per Column for DataFrame")
    print(df.count())
    print('\n')

    print("Checking unique values per Column for DataFrame")
    print(df.nunique())
    print('\n')

    print("Checking Summary Statistics for numeric columns of DataFrame")
    print(df.describe().round())
    print('\n')

    print("Checking info of DataFrame")
    df.info(show_counts=True)
    print('\n')

    print("Checking for missing values in DataFrame")
    print(df.isna().sum())
    print('\n')

    print("Checking for duplicate values in DataFrame")
    print(df.duplicated().sum())
    print('\n')

    return df

# %%
df = quick_eda(df)
# Out:
# Checking first 5 rows
#    film_id              film_title  \
# 0      402            HARPER DYING
# 1       26          ANNIE IDENTITY
# 2      366  GOLDFINGER SENSIBILITY
# 3      901             TRACY CIDER
# 4      247         DOWNHILL ENOUGH
#
#                                     film_description  film_language_id  \
# 0  A Awe-Inspiring Reflection of a Woman And a Ca...                 1
# 1  A Amazing Panorama of a Pastry Chef And a Boat...                 1
# 2  A Insightful Drama of a Mad Scientist And a Hu...                 1
# 3  A Touching Reflection of a Database Administra...                 1
# 4  A Emotional Tale of a Pastry Chef And a Forens...                 1
#
#    film_original_language_id  film_rental_duration film_rental_rate  \
# 0                       <NA>                     3      0.990000000
# 1                       <NA>                     3      0.990000000
# 2                       <NA>                     3      0.990000000
# 3                       <NA>                     3      0.990000000
# 4                       <NA>                     3      0.990000000
#
#    film_length film_replacement_cost film_rating           film_last_update  \
# 0           52          15.990000000           G 2022-09-10 16:46:03.905795
# 1           86          15.990000000           G 2022-09-10 16:46:03.905795
# 2           93          29.990000000           G 2022-09-10 16:46:03.905795
# 3          142          29.990000000           G 2022-09-10 16:46:03.905795
# 4           47          19.990000000           G 2022-09-10 16:46:03.905795
#
#                              film_special_features  \
# 0                                     ["Trailers"]
# 1                ["Commentaries","Deleted Scenes"]
# 2  ["Trailers","Commentaries","Behind the Scenes"]
# 3  ["Trailers","Commentaries","Behind the Scenes"]
# 4     ["Trailers","Commentaries","Deleted Scenes"]
#
#                                        film_fulltext
# 0  'awe':5 'awe-inspir':4 'cat':13 'confront':16 ...
# 1  'abandon':20 'amaz':4 'amus':21 'anni':1 'boat...
# 2  'chef':18 'defeat':15 'drama':5 'goldfing':1 '...
# 3  'administr':9 'build':15 'cider':2 'databas':8...
# 4  'chef':9 'desert':22 'downhil':1 'emot':4 'eno...
#
#
# Checking Shape of DataFrame (Rows, Columns)
# (1000, 13)
#
#
# Checking data types of Columns of DataFrame
# film_id                               Int64
# film_title                              str
# film_description                        str
# film_language_id                      Int64
# film_original_language_id             Int64
# film_rental_duration                  Int64
# film_rental_rate                     object
# film_length                           Int64
# film_replacement_cost                object
# film_rating                             str
# film_last_update             datetime64[us]
# film_special_features                   str
# film_fulltext                           str
# dtype: object
#
#
# Checking value counts per Column for DataFrame
# film_id                      1000
# film_title                   1000
# film_description             1000
# film_language_id             1000
# film_original_language_id       0
# film_rental_duration         1000
# film_rental_rate             1000
# film_length                  1000
# film_replacement_cost        1000
# film_rating                  1000
# film_last_update             1000
# film_special_features        1000
# film_fulltext                1000
# dtype: int64
#
#
# Checking unique values per Column for DataFrame
# film_id                      1000
# film_title                   1000
# film_description             1000
# film_language_id                1
# film_original_language_id       0
# film_rental_duration            5
# film_rental_rate                3
# film_length                   140
# film_replacement_cost          21
# film_rating                     5
# film_last_update                1
# film_special_features          15
# film_fulltext                1000
# dtype: int64
#
#
# Checking Summary Statistics for numeric columns of DataFrame
#        film_id  film_language_id  film_original_language_id  \
# count   1000.0            1000.0                        0.0
# mean     500.0               1.0                       <NA>
# min        1.0               1.0                       <NA>
# 25%      251.0               1.0                       <NA>
# 50%      500.0               1.0                       <NA>
# 75%      750.0               1.0                       <NA>
# max     1000.0               1.0                       <NA>
# std      289.0               0.0                       <NA>
#
#        film_rental_duration  film_length            film_last_update
# count                1000.0       1000.0                        1000
# mean                    5.0        115.0  2022-09-10 16:46:03.905795
# min                     3.0         46.0  2022-09-10 16:46:03.905795
# 25%                     4.0         80.0  2022-09-10 16:46:03.905795
# 50%                     5.0        114.0  2022-09-10 16:46:03.905795
# 75%                     6.0        149.0  2022-09-10 16:46:03.905795
# max                     7.0        185.0  2022-09-10 16:46:03.905795
# std                     1.0         40.0                         NaN
#
#
# Checking info of DataFrame
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   film_id                    1000 non-null   Int64
#  1   film_title                 1000 non-null   str
#  2   film_description           1000 non-null   str
#  3   film_language_id           1000 non-null   Int64
#  4   film_original_language_id  0 non-null      Int64
#  5   film_rental_duration       1000 non-null   Int64
#  6   film_rental_rate           1000 non-null   object
#  7   film_length                1000 non-null   Int64
#  8   film_replacement_cost      1000 non-null   object
#  9   film_rating                1000 non-null   str
#  10  film_last_update           1000 non-null   datetime64[us]
#  11  film_special_features      1000 non-null   str
#  12  film_fulltext              1000 non-null   str
# dtypes: Int64(5), datetime64[us](1), object(2), str(5)
# memory usage: 378.8+ KB
#
#
# Checking for missing values in DataFrame
# film_id                         0
# film_title                      0
# film_description                0
# film_language_id                0
# film_original_language_id    1000
# film_rental_duration            0
# film_rental_rate                0
# film_length                     0
# film_replacement_cost           0
# film_rating                     0
# film_last_update                0
# film_special_features           0
# film_fulltext                   0
# dtype: int64
#
#
# Checking for duplicate values in DataFrame
# 0
