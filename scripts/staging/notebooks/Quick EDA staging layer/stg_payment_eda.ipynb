# %%
from google.cloud import bigquery
import pandas as pd
import seaborn as sns
import matplotlib as plt
import os

#Setting credentials path 
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = r"C:\Users\roxan\AppData\Roaming\gcloud\application_default_credentials.json"

#Using the IDs defined in your relevant staging file
project_id = 'project-401f4646-3663-4125-aaa'
dataset_id = 'staging_db'
table_id = 'stg_payment'  

client = bigquery.Client(project=project_id)

#Querying the table that contains your renamed columns
query = f"SELECT * FROM `{project_id}.{dataset_id}.{table_id}`"

#Assigning the result directly to the variable 'df'
df = client.query(query).to_dataframe()

#Confirming the data loaded correctly
print(df.columns)
print('\n')

print(df.head())
# Out:
# C:\Users\roxan\PycharmProjects\Pagila Analytics Pipeline\.venv\Lib\site-packages\google\cloud\bigquery\table.py:2086: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# Index(['payment_id', 'payment_customer_id', 'payment_staff_id',
#        'payment_rental_id', 'payment_amount', 'payment_payment_date'],
#       dtype='str')
#
#
#    payment_id  payment_customer_id  payment_staff_id  payment_rental_id  \
# 0       22690                    1                 1              15315
# 1       28994                    1                 1               4611
# 2       18495                    1                 1               1185
# 3       22682                    1                 1              11367
# 4       29001                    1                 1               8074
#
#   payment_amount       payment_payment_date
# 0    5.990000000 2022-02-19 19:34:21.993082
# 1    5.990000000 2022-03-17 08:29:04.348881
# 2    5.990000000 2022-04-19 20:13:01.277968
# 3    0.990000000 2022-04-26 03:48:06.924227
# 4    0.990000000 2022-04-16 23:27:31.152811

# %%
def quick_eda(df):
    """
    Function performing a quick initial Exploratory Data Analysis on DataFrame df.
    """
    print("Checking first 5 rows")
    print(df.head())
    print('\n')

    print("Checking Shape of DataFrame (Rows, Columns)")
    print(df.shape)
    print('\n')

    print("Checking data types of Columns of DataFrame")
    print(df.dtypes)
    print('\n')

    print("Checking value counts per Column for DataFrame")
    print(df.count())
    print('\n')

    print("Checking unique values per Column for DataFrame")
    print(df.nunique())
    print('\n')

    print("Checking Summary Statistics for numeric columns of DataFrame")
    print(df.describe().round())
    print('\n')

    print("Checking info of DataFrame")
    df.info(show_counts=True)
    print('\n')

    print("Checking for missing values in DataFrame")
    print(df.isna().sum())
    print('\n')

    print("Checking for duplicate values in DataFrame")
    print(df.duplicated().sum())
    print('\n')

    return df

# %%
df = quick_eda(df)
# Out:
# Checking first 5 rows
#    payment_id  payment_customer_id  payment_staff_id  payment_rental_id  \
# 0       22690                    1                 1              15315
# 1       28994                    1                 1               4611
# 2       18495                    1                 1               1185
# 3       22682                    1                 1              11367
# 4       29001                    1                 1               8074
#
#   payment_amount       payment_payment_date
# 0    5.990000000 2022-02-19 19:34:21.993082
# 1    5.990000000 2022-03-17 08:29:04.348881
# 2    5.990000000 2022-04-19 20:13:01.277968
# 3    0.990000000 2022-04-26 03:48:06.924227
# 4    0.990000000 2022-04-16 23:27:31.152811
#
#
# Checking Shape of DataFrame (Rows, Columns)
# (16049, 6)
#
#
# Checking data types of Columns of DataFrame
# payment_id                       Int64
# payment_customer_id              Int64
# payment_staff_id                 Int64
# payment_rental_id                Int64
# payment_amount                  object
# payment_payment_date    datetime64[us]
# dtype: object
#
#
# Checking value counts per Column for DataFrame
# payment_id              16049
# payment_customer_id     16049
# payment_staff_id        16049
# payment_rental_id       16049
# payment_amount          16049
# payment_payment_date    16049
# dtype: int64
#
#
# Checking unique values per Column for DataFrame
# payment_id              16049
# payment_customer_id       599
# payment_staff_id            2
# payment_rental_id       16044
# payment_amount             19
# payment_payment_date    16049
# dtype: int64
#
#
# Checking Summary Statistics for numeric columns of DataFrame
#        payment_id  payment_customer_id  payment_staff_id  payment_rental_id  \
# count     16049.0              16049.0           16049.0            16049.0
# mean      24074.0                297.0               1.0             8024.0
# min       16050.0                  1.0               1.0                1.0
# 25%       20062.0                148.0               1.0             4015.0
# 50%       24074.0                296.0               1.0             8023.0
# 75%       28086.0                446.0               2.0            12036.0
# max       32098.0                599.0               2.0            16049.0
# std        4633.0                172.0               1.0             4632.0
#
#              payment_payment_date
# count                       16049
# mean   2022-04-26 11:58:34.622093
# min    2022-01-23 13:03:52.212496
# 25%    2022-03-11 04:29:53.326100
# 50%    2022-04-26 18:21:00.551227
# 75%    2022-06-12 03:38:35.127874
# max    2022-07-27 10:39:20.739759
# std                           NaN
#
#
# Checking info of DataFrame
# <class 'pandas.DataFrame'>
# RangeIndex: 16049 entries, 0 to 16048
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   payment_id            16049 non-null  Int64
#  1   payment_customer_id   16049 non-null  Int64
#  2   payment_staff_id      16049 non-null  Int64
#  3   payment_rental_id     16049 non-null  Int64
#  4   payment_amount        16049 non-null  object
#  5   payment_payment_date  16049 non-null  datetime64[us]
# dtypes: Int64(4), datetime64[us](1), object(1)
# memory usage: 815.1+ KB
#
#
# Checking for missing values in DataFrame
# payment_id              0
# payment_customer_id     0
# payment_staff_id        0
# payment_rental_id       0
# payment_amount          0
# payment_payment_date    0
# dtype: int64
#
#
# Checking for duplicate values in DataFrame
# 0
