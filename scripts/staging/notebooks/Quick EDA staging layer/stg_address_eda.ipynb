# %%
from google.cloud import bigquery
import pandas as pd
import seaborn as sns
import matplotlib as plt
import os

#Setting credentials path 
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = r"C:\Users\roxan\AppData\Roaming\gcloud\application_default_credentials.json"

#Using the IDs defined in your relevant staging file
project_id = 'project-401f4646-3663-4125-aaa'
dataset_id = 'staging_db'
table_id = 'stg_address'  

client = bigquery.Client(project=project_id)

#Querying the table that contains your renamed columns
query = f"SELECT * FROM `{project_id}.{dataset_id}.{table_id}`"

#Assigning the result directly to the variable 'df'
df = client.query(query).to_dataframe()

#Confirming the data loaded correctly
print(df.columns)
print('\n')
display(df.head())
# Out:
# C:\Users\roxan\PycharmProjects\Pagila Analytics Pipeline\.venv\Lib\site-packages\google\cloud\bigquery\table.py:2086: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# Index(['address_id', 'address_address', 'address_address2', 'address_district',
#        'address_city_id', 'address_postal_code', 'address_phone',
#        'address_last_update'],
#       dtype='str')
#    address_id        address_address address_address2 address_district  \
# 0           3      23 Workhaven Lane              NaN          Alberta
# 1           1      47 MySakila Drive              NaN          Alberta
# 2           4   1411 Lillydale Drive              NaN              QLD
# 3           2     28 MySQL Boulevard              NaN              QLD
# 4          30  18 Duisburg Boulevard
#
#    address_city_id address_postal_code address_phone address_last_update
# 0              300                       14033335568 2022-02-15 09:45:30
# 1              300                                   2022-02-15 09:45:30
# 2              576                        6172235589 2022-02-15 09:45:30
# 3              576                                   2022-02-15 09:45:30
# 4              121               58327  998009777982 2022-02-15 09:45:30

# %%
def quick_eda(df):
    """
    Function performing a quick initial Exploratory Data Analysis on DataFrame df.
    """
    print("Checking first 5 rows")
    print(df.head())
    print('\n')

    print("Checking Shape of DataFrame (Rows, Columns)")
    print(df.shape)
    print('\n')

    print("Checking data types of Columns of DataFrame")
    print(df.dtypes)
    print('\n')

    print("Checking value counts per Column for DataFrame")
    print(df.count())
    print('\n')

    print("Checking unique values per Column for DataFrame")
    print(df.nunique())
    print('\n')

    #print("Checking Summary Statistics for numeric columns of DataFrame")
    #print(df.describe().round())
    #print('\n')

    print("Checking info of DataFrame")
    df.info(show_counts=True)
    print('\n')

    print("Checking for missing values in DataFrame")
    print(df.isna().sum())
    print('\n')

    print("Checking for duplicate values in DataFrame")
    print(df.duplicated().sum())
    print('\n')

    return df

# %%
df = quick_eda(df)
# Out:
# Checking first 5 rows
#    address_id        address_address address_address2 address_district  \
# 0           3      23 Workhaven Lane              NaN          Alberta
# 1           1      47 MySakila Drive              NaN          Alberta
# 2           4   1411 Lillydale Drive              NaN              QLD
# 3           2     28 MySQL Boulevard              NaN              QLD
# 4          30  18 Duisburg Boulevard
#
#    address_city_id address_postal_code address_phone address_last_update
# 0              300                       14033335568 2022-02-15 09:45:30
# 1              300                                   2022-02-15 09:45:30
# 2              576                        6172235589 2022-02-15 09:45:30
# 3              576                                   2022-02-15 09:45:30
# 4              121               58327  998009777982 2022-02-15 09:45:30
#
#
# Checking Shape of DataFrame (Rows, Columns)
# (603, 8)
#
#
# Checking data types of Columns of DataFrame
# address_id                      Int64
# address_address                   str
# address_address2                  str
# address_district                  str
# address_city_id                 Int64
# address_postal_code               str
# address_phone                     str
# address_last_update    datetime64[us]
# dtype: object
#
#
# Checking value counts per Column for DataFrame
# address_id             603
# address_address        603
# address_address2       599
# address_district       603
# address_city_id        603
# address_postal_code    603
# address_phone          603
# address_last_update    603
# dtype: int64
#
#
# Checking unique values per Column for DataFrame
# address_id             603
# address_address        603
# address_address2         1
# address_district       378
# address_city_id        599
# address_postal_code    597
# address_phone          602
# address_last_update      1
# dtype: int64
#
#
# Checking info of DataFrame
# <class 'pandas.DataFrame'>
# RangeIndex: 603 entries, 0 to 602
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   address_id           603 non-null    Int64
#  1   address_address      603 non-null    str
#  2   address_address2     599 non-null    str
#  3   address_district     603 non-null    str
#  4   address_city_id      603 non-null    Int64
#  5   address_postal_code  603 non-null    str
#  6   address_phone        603 non-null    str
#  7   address_last_update  603 non-null    datetime64[us]
# dtypes: Int64(2), datetime64[us](1), str(5)
# memory usage: 65.5 KB
#
#
# Checking for missing values in DataFrame
# address_id             0
# address_address        0
# address_address2       4
# address_district       0
# address_city_id        0
# address_postal_code    0
# address_phone          0
# address_last_update    0
# dtype: int64
#
#
# Checking for duplicate values in DataFrame
# 0
