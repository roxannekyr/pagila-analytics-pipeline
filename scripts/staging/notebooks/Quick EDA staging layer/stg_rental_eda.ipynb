# %%
from google.cloud import bigquery
import pandas as pd
import seaborn as sns
import matplotlib as plt
import os

#Setting credentials path 
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = r"C:\Users\roxan\AppData\Roaming\gcloud\application_default_credentials.json"

#Using the IDs defined in your relevant staging file
project_id = 'project-401f4646-3663-4125-aaa'
dataset_id = 'staging_db'
table_id = 'stg_rental'  

client = bigquery.Client(project=project_id)

#Querying the table that contains your renamed columns
query = f"SELECT * FROM `{project_id}.{dataset_id}.{table_id}`"

#Assigning the result directly to the variable 'df'
df = client.query(query).to_dataframe()

#Confirming the data loaded correctly
print(df.columns)
print('\n')

display(df.head())
# Out:
# C:\Users\roxan\PycharmProjects\Pagila Analytics Pipeline\.venv\Lib\site-packages\google\cloud\bigquery\table.py:2086: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
# Index(['rental_id', 'rental_rental_date', 'rental_inventory_id',
#        'rental_customer_id', 'rental_return_date', 'rental_staff_id',
#        'rental_last_update'],
#       dtype='str')
#    rental_id  rental_rental_date  rental_inventory_id  rental_customer_id  \
# 0        573 2022-05-28 09:35:23                 4020                   1
# 1       1476 2022-06-15 20:08:46                 1407                   1
# 2       1725 2022-06-16 14:18:57                  726                   1
# 3       2363 2022-06-18 12:33:59                 3497                   1
# 4       3284 2022-06-21 05:24:45                 4566                   1
#
#    rental_return_date  rental_staff_id  rental_last_update
# 0 2022-06-03 05:32:23                1 2022-02-16 02:30:53
# 1 2022-06-25 01:26:46                1 2022-02-16 02:30:53
# 2 2022-06-17 20:05:57                1 2022-02-16 02:30:53
# 3 2022-06-19 16:40:59                1 2022-02-16 02:30:53
# 4 2022-06-28 02:28:45                1 2022-02-16 02:30:53

# %%
def quick_eda(df):
    """
    Function performing a quick initial Exploratory Data Analysis on DataFrame df.
    """
    print("Checking first 5 rows")
    print(df.head())
    print('\n')

    print("Checking Shape of DataFrame (Rows, Columns)")
    print(df.shape)
    print('\n')

    print("Checking data types of Columns of DataFrame")
    print(df.dtypes)
    print('\n')

    print("Checking value counts per Column for DataFrame")
    print(df.count())
    print('\n')

    print("Checking unique values per Column for DataFrame")
    print(df.nunique())
    print('\n')

    #print("Checking Summary Statistics for numeric columns of DataFrame")
    #print(df.describe().round())
    #print('\n')

    print("Checking info of DataFrame")
    df.info(show_counts=True)
    print('\n')

    print("Checking for missing values in DataFrame")
    print(df.isna().sum())
    print('\n')

    print("Checking for duplicate values in DataFrame")
    print(df.duplicated().sum())
    print('\n')

    return df

# %%
df = quick_eda(df)
# Out:
# Checking first 5 rows
#    rental_id  rental_rental_date  rental_inventory_id  rental_customer_id  \
# 0        573 2022-05-28 09:35:23                 4020                   1
# 1       1476 2022-06-15 20:08:46                 1407                   1
# 2       1725 2022-06-16 14:18:57                  726                   1
# 3       2363 2022-06-18 12:33:59                 3497                   1
# 4       3284 2022-06-21 05:24:45                 4566                   1
#
#    rental_return_date  rental_staff_id  rental_last_update
# 0 2022-06-03 05:32:23                1 2022-02-16 02:30:53
# 1 2022-06-25 01:26:46                1 2022-02-16 02:30:53
# 2 2022-06-17 20:05:57                1 2022-02-16 02:30:53
# 3 2022-06-19 16:40:59                1 2022-02-16 02:30:53
# 4 2022-06-28 02:28:45                1 2022-02-16 02:30:53
#
#
# Checking Shape of DataFrame (Rows, Columns)
# (16044, 7)
#
#
# Checking data types of Columns of DataFrame
# rental_id                       Int64
# rental_rental_date     datetime64[us]
# rental_inventory_id             Int64
# rental_customer_id              Int64
# rental_return_date     datetime64[us]
# rental_staff_id                 Int64
# rental_last_update     datetime64[us]
# dtype: object
#
#
# Checking value counts per Column for DataFrame
# rental_id              16044
# rental_rental_date     16044
# rental_inventory_id    16044
# rental_customer_id     16044
# rental_return_date     15861
# rental_staff_id        16044
# rental_last_update     16044
# dtype: int64
#
#
# Checking unique values per Column for DataFrame
# rental_id              16044
# rental_rental_date     15815
# rental_inventory_id     4580
# rental_customer_id       599
# rental_return_date     15836
# rental_staff_id            2
# rental_last_update         3
# dtype: int64
#
#
# Checking info of DataFrame
# <class 'pandas.DataFrame'>
# RangeIndex: 16044 entries, 0 to 16043
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   rental_id            16044 non-null  Int64
#  1   rental_rental_date   16044 non-null  datetime64[us]
#  2   rental_inventory_id  16044 non-null  Int64
#  3   rental_customer_id   16044 non-null  Int64
#  4   rental_return_date   15861 non-null  datetime64[us]
#  5   rental_staff_id      16044 non-null  Int64
#  6   rental_last_update   16044 non-null  datetime64[us]
# dtypes: Int64(4), datetime64[us](3)
# memory usage: 940.2 KB
#
#
# Checking for missing values in DataFrame
# rental_id                0
# rental_rental_date       0
# rental_inventory_id      0
# rental_customer_id       0
# rental_return_date     183
# rental_staff_id          0
# rental_last_update       0
# dtype: int64
#
#
# Checking for duplicate values in DataFrame
# 0
